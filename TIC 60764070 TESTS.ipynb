# %%
import lightkurve as lk
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal
import pandas as pd
# Target TIC ID
tic_id = "  60764070"

# Search for all SPOC light curves from TESS
sr = lk.search_lightcurve(f"TIC {tic_id}", mission="TESS", author="SPOC")

# Download light curves (PDCSAP_FLUX only)
lcs = sr.download_all(flux_column="pdcsap_flux", quality_bitmask="default")

results = []

# Loop over each sector
for i, lc_sector in enumerate(lcs):
    print(f"\n⎯⎯⎯⎯ Sector {i+1} ⎯⎯⎯⎯")
    print(f"Sector: {lc_sector.sector}")

    # Clean and normalize light curve
    lc_clean = lc_sector.normalize(unit="percent").remove_nans().remove_outliers(sigma=5)
    
    # Flatten for long-term trends
    lc_flat = lc_clean.flatten(window_length=401)

    # Plot raw and flattened lightcurve
    fig, ax = plt.subplots(2, 1, figsize=(10, 5), sharex=True, dpi=120)
    lc_clean.plot(ax=ax[0], label="Normalized")
    ax[0].set_ylabel("Flux [%]")
    ax[0].legend()
    
    lc_flat.plot(ax=ax[1], label="Flattened")
    ax[1].set_ylabel("Detrended Flux [%]")
    ax[1].set_xlabel("Time – 2457000 [BTJD days]")
    ax[1].legend()
    plt.suptitle(f"TIC {tic_id} – Sector {i+1}")
    plt.tight_layout()
    plt.show()

     # Automatically set maximum period = half of observation span
    time_span = lc_flat.time.value.ptp()  # days
    max_period = time_span / 2
    print(f"Time span: {time_span:.2f} days → max search period: {max_period:.2f} days")

    # Lomb-Scargle periodogram
    periodogram = lc_flat.to_periodogram(method="lombscargle",
                                         minimum_period=0.1,
                                         maximum_period=max_period)
    
    best_period = periodogram.period_at_max_power
    best_power = periodogram.max_power

    # Estimate error using FWHM of the peak
    periods = periodogram.period.value
    powers = periodogram.power.value

    half_max = best_power / 2
    above_half = np.where(powers >= half_max)[0]
    
    if len(above_half) > 1:
        fwhm_range = periods[above_half]
        period_error = np.abs(fwhm_range[-1] - fwhm_range[0]) / 2
    else:
        period_error = np.nan  # can't estimate if peak is too sharp

    print(f"Best LS period: {best_period:.4f} ± {period_error:.4f} days")
    # Plot the periodogram
    periodogram.plot(title=f"Periodogram – Sector {i+1}")
    plt.axvline(best_period.value, color='r', linestyle='--', label="Best Period")
    if len(above_half) > 1:
        plt.axvspan(fwhm_range[0], fwhm_range[-1], color='gray', alpha=0.3, label='FWHM range')
    plt.legend()
    plt.show()
    
#Store result
    results.append({
        "Sector": lc_sector.sector,
        "LS_period_d": best_period,
        "LS_err_d": period_error
    })

# Convert to DataFrame
df = pd.DataFrame(results, columns=["Sector", "LS_period_d", "LS_err_d"])
print("\nSummary Table of Periods:")
print(df)

# Save to CSV
csvfile = f"TIC{tic_id}_periods_table.csv"
df.to_csv(csvfile, index=False)
print(f"\nSaved table -> {csvfile}")
# Out:
# ⎯⎯⎯⎯ Sector 1 ⎯⎯⎯⎯
# Sector: 8
# Time span: 24.02 days → max search period: 12.01 days
# Best LS period: 0.1286 d ± 0.0053 days
# ⎯⎯⎯⎯ Sector 2 ⎯⎯⎯⎯
# Sector: 35
# Time span: 23.96 days → max search period: 11.98 days
# Best LS period: 0.1286 d ± 0.0049 days
# ⎯⎯⎯⎯ Sector 3 ⎯⎯⎯⎯
# Sector: 35
# Time span: 23.96 days → max search period: 11.98 days
# Best LS period: 0.1286 d ± 0.0006 days
# ⎯⎯⎯⎯ Sector 4 ⎯⎯⎯⎯
# Sector: 62
# Time span: 24.64 days → max search period: 12.32 days
# Best LS period: 0.1286 d ± 0.0050 days
# ⎯⎯⎯⎯ Sector 5 ⎯⎯⎯⎯
# Sector: 62
# Time span: 24.64 days → max search period: 12.32 days
# Best LS period: 0.1286 d ± 0.0050 days
# ⎯⎯⎯⎯ Sector 6 ⎯⎯⎯⎯
# Sector: 89
# Time span: 27.33 days → max search period: 13.67 days
# Best LS period: 0.1286 d ± 0.0049 days
# ⎯⎯⎯⎯ Sector 7 ⎯⎯⎯⎯
# Sector: 89
# Time span: 27.33 days → max search period: 13.67 days
# Best LS period: 0.1286 d ± 0.0003 days
# Summary Table of Periods:
#    Sector            LS_period_d  LS_err_d
# 0       8  0.12860590734041044 d  0.005324
# 1      35  0.12855873073522792 d  0.004867
# 2      35  0.12855252167310616 d  0.000617
# 3      62  0.12860640653925068 d  0.004976
# 4      62   0.1286076149776054 d  0.004976
# 5      89  0.12855925827533782 d  0.004881
# 6      89  0.12855163676185344 d  0.000303
#
# Saved table -> TIC  60764070_periods_table.csv

# %%
lc_fold_ls = lc_flat.fold(period= 0.12861)
lc_fold_ls.plot()
# Out:
# <Axes: xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %%
lc_fold_bin = lc_fold_ls.bin(bins=200)

lc_fold_ls.plot(alpha=0.2, label="Raw", marker='.', linestyle='none')  # raw data
lc_fold_bin.scatter(label="Binned", color="orange")  # binned data

plt.legend()
plt.xlabel("Phase")
plt.ylabel("Flux")
plt.title("Phase-Folded Light Curve (Raw vs. Binned)")
# Out:
# Text(0.5, 1.0, 'Phase-Folded Light Curve (Raw vs. Binned)')

# %%
import lightkurve as lk

# Example: search by TIC ID
search_result = lk.search_lightcurve("TIC 60764070", mission="TESS")
print(search_result)
# Out:
# SearchResult containing 15 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 08 2019              SPOC     120    60764070      0.0
#   1 TESS Sector 35 2021              SPOC      20    60764070      0.0
#   2 TESS Sector 35 2021              SPOC     120    60764070      0.0
#   3 TESS Sector 62 2023              SPOC      20    60764070      0.0
#   4 TESS Sector 62 2023              SPOC     120    60764070      0.0
#   5 TESS Sector 89 2025              SPOC      20    60764070      0.0
#   6 TESS Sector 89 2025              SPOC     120    60764070      0.0
#   7 TESS Sector 08 2019         TESS-SPOC    1800    60764070      0.0
#   8 TESS Sector 35 2021         TESS-SPOC     600    60764070      0.0
#   9 TESS Sector 62 2023         TESS-SPOC     200    60764070      0.0
#  10 TESS Sector 08 2019               QLP    1800    60764070      0.0
#  11 TESS Sector 35 2021               QLP     600    60764070      0.0
#  12 TESS Sector 62 2023               QLP     200    60764070      0.0
#  13 TESS Sector 89 2025               QLP     200    60764070      0.0
#  14 TESS Sector 08 2019 GSFC-ELEANOR-LITE    1800    60764070      0.0

# %%
import numpy as np

# Assume 'folded' is your folded light curve object
folded = lc_flat.fold(period= 0.3213)
amp = np.max(folded.flux.value) - np.min(folded.flux.value)
amp_percent = amp * 100
print(f"Peak-to-peak amplitude: {amp_percent:.2f}%")
# Out:
# Peak-to-peak amplitude: 6.03%
